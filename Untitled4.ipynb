# %%
name = input("Enter student name: ")
marks = float(input("Enter marks: "))
student = {
    "name": name,
    "marks": marks
}
print("Student Dictionary:", student)
# Out:
# Enter student name:  aaa
# Enter marks:  95
# Student Dictionary: {'name': 'aaa', 'marks': 95.0}

# %%
fruits = {
    "Apple": 120,
    "Banana": 40,
    "Orange": 80,
    "Mango": 150,
    "Grapes": 90
}
print("Fruit Dictionary:", fruits)
# Out:
# Fruit Dictionary: {'Apple': 120, 'Banana': 40, 'Orange': 80, 'Mango': 150, 'Grapes': 90}

# %%
employees = {
    "Ravi": 50000,
    "Priya": 60000,
    "Amit": 55000
}
name = input("Enter employee name: ")
if name in employees:
    print("Salary:", employees[name])
else:
    print("Employee not found")
# Out:
# Enter employee name:  bbb
# Employee not found

# %%
countries = {
    "India": "New Delhi",
    "USA": "Washington D.C.",
    "Japan": "Tokyo",
    "France": "Paris"
}
print("Countries and Capitals:")
for country, capital in countries.items():
    print(country, ":", capital)
# Out:
# Countries and Capitals:
# India : New Delhi
# USA : Washington D.C.
# Japan : Tokyo
# France : Paris

# %%
student = {
    "name": "Rahul",
    "marks": 75
}
new_marks = float(input("Enter new marks: "))
student["marks"] = new_marks

print("Updated Dictionary:", student)
# Out:
# Enter new marks:  97
# Updated Dictionary: {'name': 'Rahul', 'marks': 97.0}

# %%
inventory = {
    "Laptop": 10,
    "Mouse": 25,
    "Keyboard": 15
}
product = input("Enter product name: ")
amount = int(input("Enter quantity to add: "))
if product in inventory:
    inventory[product] += amount
    print("Updated Inventory:", inventory)
else:
    print("Product not found")
# Out:
# Enter product name:  pen
# Enter quantity to add:  34
# Product not found
