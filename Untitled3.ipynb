# %%
#Write a program to take input of 5 elements from user and create a list
#Write a program to print all th elements of the list
#Write a program to add element given by user at the end of the list
#Write a program to ask index element from user and add that element at that index in the list
#Write a program to ask from user and remove the element at the index from the list, also remove the first and last element
#Write a program to ask the user which element to remove from list and remove it
#Delete the list

# %%
my_list = []
for i in range(5):
    element = input(f"Enter element {i + 1}: ")
    my_list.append(element)
print("List:", my_list)
# Out:
# Enter element 1:  3
# Enter element 2:  4
# Enter element 3:  5
# Enter element 4:  6
# Enter element 5:  7
# List: ['3', '4', '5', '6', '7']

# %%
my_list = [10, 20, 30, 40, 50]

print("Elements of the list:")
for element in my_list:
    print(element)
# Out:
# Elements of the list:
# 10
# 20
# 30
# 40
# 50

# %%
my_list = [10, 20, 30, 40, 50]
element = input("Enter element to add at the end: ")
my_list.append(element)
print("Updated List:", my_list)
# Out:
# Enter element to add at the end:  8
# Updated List: [10, 20, 30, 40, 50, '8']

# %%
my_list = [10, 20, 30, 40, 50]
index = int(input("Enter index: "))
element = input("Enter element to insert: ")
my_list.insert(index, element)
print("Updated List:", my_list)
# Out:
# Enter index:  0
# Enter element to insert:  9
# Updated List: ['9', 10, 20, 30, 40, 50]

# %%
my_list = [10, 20, 30, 40, 50]
index = int(input("Enter index to remove: "))
if 0 <= index < len(my_list):
    my_list.pop(index)
if len(my_list) > 0:
    my_list.pop(0)
if len(my_list) > 0:
    my_list.pop(-1)  
print("Updated List:", my_list)
# Out:
# Enter index to remove:  4
# Updated List: [20, 30]

# %%
my_list = [10, 20, 30, 40, 50]

element = int(input("Enter element to remove: "))

if element in my_list:
    my_list.remove(element)
    print("Updated List:", my_list)
else:
    print("Element not found in the list.")
